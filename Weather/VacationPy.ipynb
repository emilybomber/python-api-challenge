# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
# !pip install cartopy
# !pip install geoviews
# !pip install pyproj

# Import API key
from api_keys import geoapify_key
# Out:
# Collecting cartopy
#   Obtaining dependency information for cartopy from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\eannb\anaconda3\lib\site-packages (from cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\eannb\anaconda3\lib\site-packages (from cartopy) (3.7.2)
# Collecting shapely>=1.7 (from cartopy)
#   Obtaining dependency information for shapely>=1.7 from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: packaging>=20 in c:\users\eannb\anaconda3\lib\site-packages (from cartopy) (23.1)
# Collecting pyshp>=2.1 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/46.5 kB ? eta -:--:--
#      -------------------------------------- 46.5/46.5 kB 772.3 kB/s eta 0:00:00
# Collecting pyproj>=3.1.0 (from cartopy)
#   Obtaining dependency information for pyproj>=3.1.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in c:\users\eannb\anaconda3\lib\site-packages (from pyproj>=3.1.0->cartopy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\eannb\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.2 MB 5.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.2 MB 10.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/11.2 MB 11.5 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.2 MB 11.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/11.2 MB 12.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.2 MB 12.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/11.2 MB 12.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.8/11.2 MB 13.3 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.2 MB 13.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.1/11.2 MB 13.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.7/11.2 MB 13.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.2 MB 13.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.2 MB 13.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.4/11.2 MB 13.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.0/11.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.2 MB 13.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.2 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.2 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 13.6 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.7/6.1 MB 15.7 MB/s eta 0:00:01
#    -------- ------------------------------- 1.3/6.1 MB 13.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.1 MB 14.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.1 MB 14.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.1 MB 14.5 MB/s eta 0:00:01
#    -------------------------- ------------- 4.1/6.1 MB 14.5 MB/s eta 0:00:01
#    ------------------------------- -------- 4.8/6.1 MB 14.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.4/6.1 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 13.4 MB/s eta 0:00:00
# Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.4 MB 13.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 15.2 MB/s eta 0:00:00
# Installing collected packages: shapely, pyshp, pyproj, cartopy
# Successfully installed cartopy-0.22.0 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.2
# Collecting geoviews
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/72/10/81aaca3edf7d7bfb14a9a17b5effaeb9dcba54ba9703b392bb17241e45ea/geoviews-1.11.0-py2.py3-none-any.whl.metadata
#   Downloading geoviews-1.11.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (3.2.1)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: packaging in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (1.24.3)
# Requirement already satisfied: shapely in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: param in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (1.2.3)
# Requirement already satisfied: pyproj in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\users\eannb\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\eannb\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\eannb\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\eannb\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\eannb\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in c:\users\eannb\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\eannb\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in c:\users\eannb\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eannb\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eannb\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eannb\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\eannb\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\eannb\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\eannb\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\eannb\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\eannb\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\eannb\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\eannb\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\eannb\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eannb\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\eannb\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.16)
# Downloading geoviews-1.11.0-py2.py3-none-any.whl (511 kB)
#    ---------------------------------------- 0.0/511.2 kB ? eta -:--:--
#     --------------------------------------- 10.2/511.2 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/511.2 kB 435.7 kB/s eta 0:00:02
#    -------- ----------------------------- 112.6/511.2 kB 939.4 kB/s eta 0:00:01
#    ------------------------ --------------- 317.4/511.2 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 511.2/511.2 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: geoviews
# Successfully installed geoviews-1.11.0
# Requirement already satisfied: pyproj in c:\users\eannb\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\eannb\anaconda3\lib\site-packages (from pyproj) (2023.7.22)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0        0           adamstown -25.0660 -130.1015     73.42        85
# 1        1      port elizabeth -33.9180   25.5701     65.32        88
# 2        2               vadso  70.0744   29.7487     19.56        73
# 3        3  sao felix do xingu  -6.6447  -51.9950     92.48        47
# 4        4            waitangi -43.9535 -176.5597     49.82        93
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       25.01      PN  1700332061
# 1          20        2.30      ZA  1700332062
# 2          20       11.50      NO  1700332062
# 3          84        1.79      BR  1700332063
# 4         100        5.01      NZ  1700332064

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    size="Humidity",
    scale=1,
    color="City",
    alpha= 0.5,
    tiles=True
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 21) \
    & (city_data_df["Wind Speed"] < 4.5) \
    & (city_data_df["Cloudiness"] == 0)
]
# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna()

# Display sample data
narrowed_city_df
# Out:
#      City_ID        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 538      538  stolbovaya  55.2528  37.4853     22.44        69           0
#
#      Wind Speed Country        Date
# 538        2.46      RU  1700332521

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowed_city_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#            City Country      Lat      Lng  Humidity Hotel Name
# 538  stolbovaya      RU  55.2528  37.4853        69

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey":geoapify_key,
    "categories": 'accommodation.hotel'
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# stolbovaya - nearest hotel: Меридиан
#            City Country      Lat      Lng  Humidity Hotel Name
# 538  stolbovaya      RU  55.2528  37.4853        69   Меридиан

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot 
map_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo=True, 
    size="Humidity", 
    scale=1,
    color="City",
    alpha= 0.5,
    tiles=True,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
